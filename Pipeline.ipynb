# %% [markdown]
# <a href="https://colab.research.google.com/github/usffish/IS-test/blob/main/Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Qwen Fine-Tuning and Evaluation Pipeline
# This notebook automates the process of environment setup, data preparation, fine-tuning, and performance comparison for the Qwen model.

# %% [markdown]
# ## 1. Environment Configuration
# Installing necessary libraries and setting up Hugging Face authentication.

# %%
# !pip install transformers trl peft datasets accelerate -q
# !pip install torchao --upgrade -q
# !pip install torchvision --upgrade -q

# %%
from google.colab import userdata
import os
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

# %% [markdown]
# ## 2. Repository and Data Setup
# Cloning the source repository and preparing the dataset.

# %%
# %cd /content
# !git clone -b colab-training https://github.com/usffish/IS-test
# %cd IS-test
# !git pull

# %%
# !pip install -r requirements.txt
# !python Data.py

# %% [markdown]
# ## 3. Model Training
# Executing the fine-tuning process using the `main.py` script.

# %%
# !python main.py

# %% [markdown]
# ## 4. Evaluation and Benchmarking
# Comparing the baseline model performance against our fine-tuned version.

# %%
# !python test.py --model Qwen/Qwen2.5-1.5B --output results/baseline.json
# !python test.py --model ./tuned-qwen --output results/finetuned.json

# %%
# !python test.py --compare results/baseline.json results/finetuned.json

# %% [markdown]
# ## 5. Exporting Results
# Packaging the fine-tuned model weights and evaluation logs for download.

# %%
# !zip -r tuned-qwen.zip /content/IS-test/tuned-qwen
# !zip -r results.zip /content/IS-test/results

# %% [markdown]
# # Qwen Fine-Tuning and Evaluation Pipeline
# This notebook automates the process of environment setup, data preparation, fine-tuning, and performance comparison for the Qwen model.

# %% [markdown]
# ## 1. Environment Configuration
# Installing necessary libraries and setting up Hugging Face authentication.

# %%
# !pip install transformers trl peft datasets accelerate -q
# !pip install torchao --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.0/751.0 kB 52.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 53.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 52.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 124.2 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Repository and Data Setup
# Cloning the source repository and preparing the dataset.

# %%
# %cd /content
# !git clone -b colab-training https://github.com/usffish/IS-test
# %cd IS-test
# Out:
# /content
# Cloning into 'IS-test'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 79 (delta 33), reused 62 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (79/79), 21.52 KiB | 21.52 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
# /content/IS-test

# %%
# %cd /content/IS-test
# !git pull
# Out:
# /content/IS-test
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 348 bytes | 348.00 KiB/s, done.
# From https://github.com/usffish/IS-test
#    77669a2..42e7e01  colab-training -> origin/colab-training
# Updating 77669a2..42e7e01
# Fast-forward
#  test.py | 5 +++--
#  1 file changed, 3 insertions(+), 2 deletions(-)

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 7.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.3/532.3 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 155.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.6/663.6 kB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 140.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.2/366.2 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 MB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.0/206.0 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 40.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.5/201.5 MB 3.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
import os
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

# %%
# !python Data.py

# %% [markdown]
# ## 3. Model Training
# Executing the fine-tuning process using the `main.py` script.

# %%
# !python main.py
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# Map: 100% 7473/7473 [00:00<00:00, 26951.32 examples/s]
# Map: 100% 1319/1319 [00:00<00:00, 26620.31 examples/s]
# Map: 100% 448/448 [00:00<00:00, 1632.21 examples/s]
# config.json: 100% 684/684 [00:00<00:00, 2.52MB/s]
# model.safetensors: 100% 3.09G/3.09G [00:09<00:00, 342MB/s]
# Loading weights: 100% 338/338 [00:00<00:00, 911.89it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 138/138 [00:00<00:00, 680kB/s]
# tokenizer_config.json: 7.23kB [00:00, 14.6MB/s]
# vocab.json: 2.78MB [00:00, 3.77MB/s]
# merges.txt: 1.67MB [00:00, 2.11MB/s]
# tokenizer.json: 7.03MB [00:00, 114MB/s]
# Adding EOS to train dataset: 100% 7831/7831 [00:05<00:00, 1330.60 examples/s]
# Tokenizing train dataset: 100% 7831/7831 [00:10<00:00, 747.78 examples/s]
# ...

# %% [markdown]
# ## 4. Evaluation and Benchmarking
# Comparing the baseline model performance against our fine-tuned version.

# %%
# !pip install torchvision --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 144.8 MB/s eta 0:00:00

# %%
# !python test.py --model Qwen/Qwen2.5-1.5B --output results/baseline.json
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# W0519 01:54:35.725000 34646 torch/utils/_pytree.py:630] <enum 'KernelPreference'> is an Enum subclass and is now natively supported by torch.compile as an opaque value type. Calling register_constant() on Enum subclasses is deprecated and will be an error in a future release.
# W0519 01:54:35.754000 34646 torch/utils/_pytree.py:630] <enum 'ScaleCalculationMode'> is an Enum subclass and is now natively supported by torch.compile as an opaque value type. Calling register_constant() on Enum subclasses is deprecated and will be an error in a future release.
# Loading weights: 100% 338/338 [00:00<00:00, 5948.82it/s]
# [transformers] Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# [transformers] Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# [transformers] Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# ...

# %%
# !zip -r tuned-qwen.zip /content/IS-test/tuned-qwen
# Out:
#   adding: content/IS-test/tuned-qwen/ (stored 0%)
#   adding: content/IS-test/tuned-qwen/training_args.bin (deflated 53%)
#   adding: content/IS-test/tuned-qwen/adapter_config.json (deflated 59%)
#   adding: content/IS-test/tuned-qwen/chat_template.jinja (deflated 71%)
#   adding: content/IS-test/tuned-qwen/README.md (deflated 65%)
#   adding: content/IS-test/tuned-qwen/tokenizer_config.json (deflated 60%)
#   adding: content/IS-test/tuned-qwen/adapter_model.safetensors (deflated 8%)
#   adding: content/IS-test/tuned-qwen/tokenizer.json (deflated 81%)

# %%
# !python test.py --model ./tuned-qwen --output results/finetuned.json
# Out:
# W0519 02:28:24.041000 43337 torch/utils/_pytree.py:630] <enum 'KernelPreference'> is an Enum subclass and is now natively supported by torch.compile as an opaque value type. Calling register_constant() on Enum subclasses is deprecated and will be an error in a future release.
# W0519 02:28:24.070000 43337 torch/utils/_pytree.py:630] <enum 'ScaleCalculationMode'> is an Enum subclass and is now natively supported by torch.compile as an opaque value type. Calling register_constant() on Enum subclasses is deprecated and will be an error in a future release.
# Loading weights: 100% 338/338 [00:00<00:00, 5418.77it/s]
# Loading weights: 100% 224/224 [00:00<00:00, 4518.40it/s]
#   GSM8K [20/200] running accuracy: 65.00%
#   GSM8K [40/200] running accuracy: 65.00%
#   GSM8K [60/200] running accuracy: 68.33%
#   GSM8K [80/200] running accuracy: 68.75%
#   GSM8K [100/200] running accuracy: 68.00%
#   GSM8K [120/200] running accuracy: 67.50%
#   GSM8K [140/200] running accuracy: 69.29%
# ...

# %%
# !python test.py --compare results/baseline.json results/finetuned.json
# Out:
# ...
# Dataset        Baseline   Fine-tuned     Change
# --------------------------------------------------
# gsm8k           12.00%      65.50%   ↑53.50%
# gpqa             1.11%      26.67%   ↑25.56%
# ...

# %% [markdown]
# ## 5. Exporting Results
# Packaging the fine-tuned model weights and evaluation logs for download.

# %%
# !zip -r results.zip /content/IS-test/results
# Out:
#   adding: content/IS-test/results/ (stored 0%)
#   adding: content/IS-test/results/finetuned.json (deflated 14%)
#   adding: content/IS-test/results/baseline.json (deflated 16%)
